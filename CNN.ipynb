# %%
import os
import matplotlib.pyplot as plt
import cv2
import shutil
import random

# %% [markdown]
# Mounting Google Drive on Colab

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Transferring dataset zip file from google drive to Google colab virtual disk and extracting dataset

# %%
import numpy as np
import pandas as pd
import os

# %%
os.mkdir('Train')
os.mkdir('Test')

# %%
os.mkdir('/content/Train/Cloudy')
os.mkdir('/content/Train/Rain')
os.mkdir('/content/Train/Shine')
os.mkdir('/content/Train/Sunrise')

# %%
os.mkdir('/content/Test/Cloudy')
os.mkdir('/content/Test/Rain')
os.mkdir('/content/Test/Shine')
os.mkdir('/content/Test/Sunrise')

# %% [markdown]
# Checking the number of images each folder

# %%
image_cloud=os.listdir('/content/drive/MyDrive/Weather Image Classification/Cloudy')
len(image_cloud)
# Out:
# 817

# %%
image_rain=os.listdir('/content/drive/MyDrive/Weather Image Classification/Rain')
len(image_rain)
# Out:
# 728

# %%
image_shine=os.listdir('/content/drive/MyDrive/Weather Image Classification/Shine')
len(image_shine)
# Out:
# 553

# %%
image_sunrise=os.listdir('/content/drive/MyDrive/Weather Image Classification/Sunrise')
len(image_sunrise)
# Out:
# 657

# %% [markdown]
# Copying images to train and text files respectively
#
# Train files contain 70% of the data and test file contain 30% of the data

# %%
import shutil
import random

# %%
random.shuffle(image_cloud)
cloud='/content/drive/MyDrive/Weather Image Classification/Cloudy'

for i in range(570):
  images=image_cloud[i]
  image_path=os.path.join(cloud,images)
  target_path=os.path.join('/content/Train/Cloudy',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164
# copying images 165
# copying images 166
# copying images 167
# copying images 168
# copying images 169
# copying images 170
# copying images 171
# copying images 172
# copying images 173
# copying images 174
# copying images 175
# copying images 176
# copying images 177
# copying images 178
# copying images 179
# copying images 180
# copying images 181
# copying images 182
# copying images 183
# copying images 184
# copying images 185
# copying images 186
# copying images 187
# copying images 188
# copying images 189
# copying images 190
# copying images 191
# copying images 192
# copying images 193
# copying images 194
# copying images 195
# copying images 196
# copying images 197
# copying images 198
# copying images 199
# copying images 200
# copying images 201
# copying images 202
# copying images 203
# copying images 204
# copying images 205
# copying images 206
# copying images 207
# copying images 208
# copying images 209
# copying images 210
# copying images 211
# copying images 212
# copying images 213
# copying images 214
# copying images 215
# copying images 216
# copying images 217
# copying images 218
# copying images 219
# copying images 220
# copying images 221
# copying images 222
# copying images 223
# copying images 224
# copying images 225
# copying images 226
# copying images 227
# copying images 228
# copying images 229
# copying images 230
# copying images 231
# copying images 232
# copying images 233
# copying images 234
# copying images 235
# copying images 236
# copying images 237
# copying images 238
# copying images 239
# copying images 240
# copying images 241
# copying images 242
# copying images 243
# copying images 244
# copying images 245
# copying images 246
# copying images 247
# copying images 248
# copying images 249
# copying images 250
# copying images 251
# copying images 252
# copying images 253
# copying images 254
# copying images 255
# copying images 256
# copying images 257
# copying images 258
# copying images 259
# copying images 260
# copying images 261
# copying images 262
# copying images 263
# copying images 264
# copying images 265
# copying images 266
# copying images 267
# copying images 268
# copying images 269
# copying images 270
# copying images 271
# copying images 272
# copying images 273
# copying images 274
# copying images 275
# copying images 276
# copying images 277
# copying images 278
# copying images 279
# copying images 280
# copying images 281
# copying images 282
# copying images 283
# copying images 284
# copying images 285
# copying images 286
# copying images 287
# copying images 288
# copying images 289
# copying images 290
# copying images 291
# copying images 292
# copying images 293
# copying images 294
# copying images 295
# copying images 296
# copying images 297
# copying images 298
# copying images 299
# copying images 300
# copying images 301
# copying images 302
# copying images 303
# copying images 304
# copying images 305
# copying images 306
# copying images 307
# copying images 308
# copying images 309
# copying images 310
# copying images 311
# copying images 312
# copying images 313
# copying images 314
# copying images 315
# copying images 316
# copying images 317
# copying images 318
# copying images 319
# copying images 320
# copying images 321
# copying images 322
# copying images 323
# copying images 324
# copying images 325
# copying images 326
# copying images 327
# copying images 328
# copying images 329
# copying images 330
# copying images 331
# copying images 332
# copying images 333
# copying images 334
# copying images 335
# copying images 336
# copying images 337
# copying images 338
# copying images 339
# copying images 340
# copying images 341
# copying images 342
# copying images 343
# copying images 344
# copying images 345
# copying images 346
# copying images 347
# copying images 348
# copying images 349
# copying images 350
# copying images 351
# copying images 352
# copying images 353
# copying images 354
# copying images 355
# copying images 356
# copying images 357
# copying images 358
# copying images 359
# copying images 360
# copying images 361
# copying images 362
# copying images 363
# copying images 364
# copying images 365
# copying images 366
# copying images 367
# copying images 368
# copying images 369
# copying images 370
# copying images 371
# copying images 372
# copying images 373
# copying images 374
# copying images 375
# copying images 376
# copying images 377
# copying images 378
# copying images 379
# copying images 380
# copying images 381
# copying images 382
# copying images 383
# copying images 384
# copying images 385
# copying images 386
# copying images 387
# copying images 388
# copying images 389
# copying images 390
# copying images 391
# copying images 392
# copying images 393
# copying images 394
# copying images 395
# copying images 396
# copying images 397
# copying images 398
# copying images 399
# copying images 400
# copying images 401
# copying images 402
# copying images 403
# copying images 404
# copying images 405
# copying images 406
# copying images 407
# copying images 408
# copying images 409
# copying images 410
# copying images 411
# copying images 412
# copying images 413
# copying images 414
# copying images 415
# copying images 416
# copying images 417
# copying images 418
# copying images 419
# copying images 420
# copying images 421
# copying images 422
# copying images 423
# copying images 424
# copying images 425
# copying images 426
# copying images 427
# copying images 428
# copying images 429
# copying images 430
# copying images 431
# copying images 432
# copying images 433
# copying images 434
# copying images 435
# copying images 436
# copying images 437
# copying images 438
# copying images 439
# copying images 440
# copying images 441
# copying images 442
# copying images 443
# copying images 444
# copying images 445
# copying images 446
# copying images 447
# copying images 448
# copying images 449
# copying images 450
# copying images 451
# copying images 452
# copying images 453
# copying images 454
# copying images 455
# copying images 456
# copying images 457
# copying images 458
# copying images 459
# copying images 460
# copying images 461
# copying images 462
# copying images 463
# copying images 464
# copying images 465
# copying images 466
# copying images 467
# copying images 468
# copying images 469
# copying images 470
# copying images 471
# copying images 472
# copying images 473
# copying images 474
# copying images 475
# copying images 476
# copying images 477
# copying images 478
# copying images 479
# copying images 480
# copying images 481
# copying images 482
# copying images 483
# copying images 484
# copying images 485
# copying images 486
# copying images 487
# copying images 488
# copying images 489
# copying images 490
# copying images 491
# copying images 492
# copying images 493
# copying images 494
# copying images 495
# copying images 496
# copying images 497
# copying images 498
# copying images 499
# copying images 500
# copying images 501
# copying images 502
# copying images 503
# copying images 504
# copying images 505
# copying images 506
# copying images 507
# copying images 508
# copying images 509
# copying images 510
# copying images 511
# copying images 512
# copying images 513
# copying images 514
# copying images 515
# copying images 516
# copying images 517
# copying images 518
# copying images 519
# copying images 520
# copying images 521
# copying images 522
# copying images 523
# copying images 524
# copying images 525
# copying images 526
# copying images 527
# copying images 528
# copying images 529
# copying images 530
# copying images 531
# copying images 532
# copying images 533
# copying images 534
# copying images 535
# copying images 536
# copying images 537
# copying images 538
# copying images 539
# copying images 540
# copying images 541
# copying images 542
# copying images 543
# copying images 544
# copying images 545
# copying images 546
# copying images 547
# copying images 548
# copying images 549
# copying images 550
# copying images 551
# copying images 552
# copying images 553
# copying images 554
# copying images 555
# copying images 556
# copying images 557
# copying images 558
# copying images 559
# copying images 560
# copying images 561
# copying images 562
# copying images 563
# copying images 564
# copying images 565
# copying images 566
# copying images 567
# copying images 568
# copying images 569

# %%
random.shuffle(image_shine)
shine='/content/drive/MyDrive/Weather Image Classification/Shine'
for i in range(245):
  images=image_shine[i]
  image_path=os.path.join(shine,images)
  target_path=os.path.join('/content/Test/Shine',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164
# copying images 165
# copying images 166
# copying images 167
# copying images 168
# copying images 169
# copying images 170
# copying images 171
# copying images 172
# copying images 173
# copying images 174
# copying images 175
# copying images 176
# copying images 177
# copying images 178
# copying images 179
# copying images 180
# copying images 181
# copying images 182
# copying images 183
# copying images 184
# copying images 185
# copying images 186
# copying images 187
# copying images 188
# copying images 189
# copying images 190
# copying images 191
# copying images 192
# copying images 193
# copying images 194
# copying images 195
# copying images 196
# copying images 197
# copying images 198
# copying images 199
# copying images 200
# copying images 201
# copying images 202
# copying images 203
# copying images 204
# copying images 205
# copying images 206
# copying images 207
# copying images 208
# copying images 209
# copying images 210
# copying images 211
# copying images 212
# copying images 213
# copying images 214
# copying images 215
# copying images 216
# copying images 217
# copying images 218
# copying images 219
# copying images 220
# copying images 221
# copying images 222
# copying images 223
# copying images 224
# copying images 225
# copying images 226
# copying images 227
# copying images 228
# copying images 229
# copying images 230
# copying images 231
# copying images 232
# copying images 233
# copying images 234
# copying images 235
# copying images 236
# copying images 237
# copying images 238
# copying images 239
# copying images 240
# copying images 241
# copying images 242
# copying images 243
# copying images 244

# %%
random.shuffle(image_rain)
rain='/content/drive/MyDrive/Weather Image Classification/Rain'

for i in range(509):
  images=image_rain[i]
  image_path=os.path.join(rain,images)
  target_path=os.path.join('/content/Train/Rain',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164
# copying images 165
# copying images 166
# copying images 167
# copying images 168
# copying images 169
# copying images 170
# copying images 171
# copying images 172
# copying images 173
# copying images 174
# copying images 175
# copying images 176
# copying images 177
# copying images 178
# copying images 179
# copying images 180
# copying images 181
# copying images 182
# copying images 183
# copying images 184
# copying images 185
# copying images 186
# copying images 187
# copying images 188
# copying images 189
# copying images 190
# copying images 191
# copying images 192
# copying images 193
# copying images 194
# copying images 195
# copying images 196
# copying images 197
# copying images 198
# copying images 199
# copying images 200
# copying images 201
# copying images 202
# copying images 203
# copying images 204
# copying images 205
# copying images 206
# copying images 207
# copying images 208
# copying images 209
# copying images 210
# copying images 211
# copying images 212
# copying images 213
# copying images 214
# copying images 215
# copying images 216
# copying images 217
# copying images 218
# copying images 219
# copying images 220
# copying images 221
# copying images 222
# copying images 223
# copying images 224
# copying images 225
# copying images 226
# copying images 227
# copying images 228
# copying images 229
# copying images 230
# copying images 231
# copying images 232
# copying images 233
# copying images 234
# copying images 235
# copying images 236
# copying images 237
# copying images 238
# copying images 239
# copying images 240
# copying images 241
# copying images 242
# copying images 243
# copying images 244
# copying images 245
# copying images 246
# copying images 247
# copying images 248
# copying images 249
# copying images 250
# copying images 251
# copying images 252
# copying images 253
# copying images 254
# copying images 255
# copying images 256
# copying images 257
# copying images 258
# copying images 259
# copying images 260
# copying images 261
# copying images 262
# copying images 263
# copying images 264
# copying images 265
# copying images 266
# copying images 267
# copying images 268
# copying images 269
# copying images 270
# copying images 271
# copying images 272
# copying images 273
# copying images 274
# copying images 275
# copying images 276
# copying images 277
# copying images 278
# copying images 279
# copying images 280
# copying images 281
# copying images 282
# copying images 283
# copying images 284
# copying images 285
# copying images 286
# copying images 287
# copying images 288
# copying images 289
# copying images 290
# copying images 291
# copying images 292
# copying images 293
# copying images 294
# copying images 295
# copying images 296
# copying images 297
# copying images 298
# copying images 299
# copying images 300
# copying images 301
# copying images 302
# copying images 303
# copying images 304
# copying images 305
# copying images 306
# copying images 307
# copying images 308
# copying images 309
# copying images 310
# copying images 311
# copying images 312
# copying images 313
# copying images 314
# copying images 315
# copying images 316
# copying images 317
# copying images 318
# copying images 319
# copying images 320
# copying images 321
# copying images 322
# copying images 323
# copying images 324
# copying images 325
# copying images 326
# copying images 327
# copying images 328
# copying images 329
# copying images 330
# copying images 331
# copying images 332
# copying images 333
# copying images 334
# copying images 335
# copying images 336
# copying images 337
# copying images 338
# copying images 339
# copying images 340
# copying images 341
# copying images 342
# copying images 343
# copying images 344
# copying images 345
# copying images 346
# copying images 347
# copying images 348
# copying images 349
# copying images 350
# copying images 351
# copying images 352
# copying images 353
# copying images 354
# copying images 355
# copying images 356
# copying images 357
# copying images 358
# copying images 359
# copying images 360
# copying images 361
# copying images 362
# copying images 363
# copying images 364
# copying images 365
# copying images 366
# copying images 367
# copying images 368
# copying images 369
# copying images 370
# copying images 371
# copying images 372
# copying images 373
# copying images 374
# copying images 375
# copying images 376
# copying images 377
# copying images 378
# copying images 379
# copying images 380
# copying images 381
# copying images 382
# copying images 383
# copying images 384
# copying images 385
# copying images 386
# copying images 387
# copying images 388
# copying images 389
# copying images 390
# copying images 391
# copying images 392
# copying images 393
# copying images 394
# copying images 395
# copying images 396
# copying images 397
# copying images 398
# copying images 399
# copying images 400
# copying images 401
# copying images 402
# copying images 403
# copying images 404
# copying images 405
# copying images 406
# copying images 407
# copying images 408
# copying images 409
# copying images 410
# copying images 411
# copying images 412
# copying images 413
# copying images 414
# copying images 415
# copying images 416
# copying images 417
# copying images 418
# copying images 419
# copying images 420
# copying images 421
# copying images 422
# copying images 423
# copying images 424
# copying images 425
# copying images 426
# copying images 427
# copying images 428
# copying images 429
# copying images 430
# copying images 431
# copying images 432
# copying images 433
# copying images 434
# copying images 435
# copying images 436
# copying images 437
# copying images 438
# copying images 439
# copying images 440
# copying images 441
# copying images 442
# copying images 443
# copying images 444
# copying images 445
# copying images 446
# copying images 447
# copying images 448
# copying images 449
# copying images 450
# copying images 451
# copying images 452
# copying images 453
# copying images 454
# copying images 455
# copying images 456
# copying images 457
# copying images 458
# copying images 459
# copying images 460
# copying images 461
# copying images 462
# copying images 463
# copying images 464
# copying images 465
# copying images 466
# copying images 467
# copying images 468
# copying images 469
# copying images 470
# copying images 471
# copying images 472
# copying images 473
# copying images 474
# copying images 475
# copying images 476
# copying images 477
# copying images 478
# copying images 479
# copying images 480
# copying images 481
# copying images 482
# copying images 483
# copying images 484
# copying images 485
# copying images 486
# copying images 487
# copying images 488
# copying images 489
# copying images 490
# copying images 491
# copying images 492
# copying images 493
# copying images 494
# copying images 495
# copying images 496
# copying images 497
# copying images 498
# copying images 499
# copying images 500
# copying images 501
# copying images 502
# copying images 503
# copying images 504
# copying images 505
# copying images 506
# copying images 507
# copying images 508

# %%
random.shuffle(image_rain)
rain='/content/drive/MyDrive/Weather Image Classification/Rain'

for i in range(218):
  images=image_rain[i]
  image_path=os.path.join(rain,images)
  target_path=os.path.join('/content/Test/Rain',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164
# copying images 165
# copying images 166
# copying images 167
# copying images 168
# copying images 169
# copying images 170
# copying images 171
# copying images 172
# copying images 173
# copying images 174
# copying images 175
# copying images 176
# copying images 177
# copying images 178
# copying images 179
# copying images 180
# copying images 181
# copying images 182
# copying images 183
# copying images 184
# copying images 185
# copying images 186
# copying images 187
# copying images 188
# copying images 189
# copying images 190
# copying images 191
# copying images 192
# copying images 193
# copying images 194
# copying images 195
# copying images 196
# copying images 197
# copying images 198
# copying images 199
# copying images 200
# copying images 201
# copying images 202
# copying images 203
# copying images 204
# copying images 205
# copying images 206
# copying images 207
# copying images 208
# copying images 209
# copying images 210
# copying images 211
# copying images 212
# copying images 213
# copying images 214
# copying images 215
# copying images 216
# copying images 217

# %%
random.shuffle(image_shine)
shine='/content/drive/MyDrive/Weather Image Classification/Shine'
for i in range(387):
  images=image_shine[i]
  image_path=os.path.join(shine,images)
  target_path=os.path.join('/content/Train/Shine',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164
# copying images 165
# copying images 166
# copying images 167
# copying images 168
# copying images 169
# copying images 170
# copying images 171
# copying images 172
# copying images 173
# copying images 174
# copying images 175
# copying images 176
# copying images 177
# copying images 178
# copying images 179
# copying images 180
# copying images 181
# copying images 182
# copying images 183
# copying images 184
# copying images 185
# copying images 186
# copying images 187
# copying images 188
# copying images 189
# copying images 190
# copying images 191
# copying images 192
# copying images 193
# copying images 194
# copying images 195
# copying images 196
# copying images 197
# copying images 198
# copying images 199
# copying images 200
# copying images 201
# copying images 202
# copying images 203
# copying images 204
# copying images 205
# copying images 206
# copying images 207
# copying images 208
# copying images 209
# copying images 210
# copying images 211
# copying images 212
# copying images 213
# copying images 214
# copying images 215
# copying images 216
# copying images 217
# copying images 218
# copying images 219
# copying images 220
# copying images 221
# copying images 222
# copying images 223
# copying images 224
# copying images 225
# copying images 226
# copying images 227
# copying images 228
# copying images 229
# copying images 230
# copying images 231
# copying images 232
# copying images 233
# copying images 234
# copying images 235
# copying images 236
# copying images 237
# copying images 238
# copying images 239
# copying images 240
# copying images 241
# copying images 242
# copying images 243
# copying images 244
# copying images 245
# copying images 246
# copying images 247
# copying images 248
# copying images 249
# copying images 250
# copying images 251
# copying images 252
# copying images 253
# copying images 254
# copying images 255
# copying images 256
# copying images 257
# copying images 258
# copying images 259
# copying images 260
# copying images 261
# copying images 262
# copying images 263
# copying images 264
# copying images 265
# copying images 266
# copying images 267
# copying images 268
# copying images 269
# copying images 270
# copying images 271
# copying images 272
# copying images 273
# copying images 274
# copying images 275
# copying images 276
# copying images 277
# copying images 278
# copying images 279
# copying images 280
# copying images 281
# copying images 282
# copying images 283
# copying images 284
# copying images 285
# copying images 286
# copying images 287
# copying images 288
# copying images 289
# copying images 290
# copying images 291
# copying images 292
# copying images 293
# copying images 294
# copying images 295
# copying images 296
# copying images 297
# copying images 298
# copying images 299
# copying images 300
# copying images 301
# copying images 302
# copying images 303
# copying images 304
# copying images 305
# copying images 306
# copying images 307
# copying images 308
# copying images 309
# copying images 310
# copying images 311
# copying images 312
# copying images 313
# copying images 314
# copying images 315
# copying images 316
# copying images 317
# copying images 318
# copying images 319
# copying images 320
# copying images 321
# copying images 322
# copying images 323
# copying images 324
# copying images 325
# copying images 326
# copying images 327
# copying images 328
# copying images 329
# copying images 330
# copying images 331
# copying images 332
# copying images 333
# copying images 334
# copying images 335
# copying images 336
# copying images 337
# copying images 338
# copying images 339
# copying images 340
# copying images 341
# copying images 342
# copying images 343
# copying images 344
# copying images 345
# copying images 346
# copying images 347
# copying images 348
# copying images 349
# copying images 350
# copying images 351
# copying images 352
# copying images 353
# copying images 354
# copying images 355
# copying images 356
# copying images 357
# copying images 358
# copying images 359
# copying images 360
# copying images 361
# copying images 362
# copying images 363
# copying images 364
# copying images 365
# copying images 366
# copying images 367
# copying images 368
# copying images 369
# copying images 370
# copying images 371
# copying images 372
# copying images 373
# copying images 374
# copying images 375
# copying images 376
# copying images 377
# copying images 378
# copying images 379
# copying images 380
# copying images 381
# copying images 382
# copying images 383
# copying images 384
# copying images 385
# copying images 386

# %%
random.shuffle(image_shine)
shine='/content/drive/MyDrive/Weather Image Classification/Shine'
for i in range(165):
  images=image_shine[i]
  image_path=os.path.join(shine,images)
  target_path=os.path.join('/content/Test/Shine',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164

# %%
random.shuffle(image_sunrise)
sunrise='/content/drive/MyDrive/Weather Image Classification/Sunrise'
for i in range(459):
  images=image_sunrise[i]
  image_path=os.path.join(sunrise,images)
  target_path=os.path.join('/content/Train/Sunrise',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164
# copying images 165
# copying images 166
# copying images 167
# copying images 168
# copying images 169
# copying images 170
# copying images 171
# copying images 172
# copying images 173
# copying images 174
# copying images 175
# copying images 176
# copying images 177
# copying images 178
# copying images 179
# copying images 180
# copying images 181
# copying images 182
# copying images 183
# copying images 184
# copying images 185
# copying images 186
# copying images 187
# copying images 188
# copying images 189
# copying images 190
# copying images 191
# copying images 192
# copying images 193
# copying images 194
# copying images 195
# copying images 196
# copying images 197
# copying images 198
# copying images 199
# copying images 200
# copying images 201
# copying images 202
# copying images 203
# copying images 204
# copying images 205
# copying images 206
# copying images 207
# copying images 208
# copying images 209
# copying images 210
# copying images 211
# copying images 212
# copying images 213
# copying images 214
# copying images 215
# copying images 216
# copying images 217
# copying images 218
# copying images 219
# copying images 220
# copying images 221
# copying images 222
# copying images 223
# copying images 224
# copying images 225
# copying images 226
# copying images 227
# copying images 228
# copying images 229
# copying images 230
# copying images 231
# copying images 232
# copying images 233
# copying images 234
# copying images 235
# copying images 236
# copying images 237
# copying images 238
# copying images 239
# copying images 240
# copying images 241
# copying images 242
# copying images 243
# copying images 244
# copying images 245
# copying images 246
# copying images 247
# copying images 248
# copying images 249
# copying images 250
# copying images 251
# copying images 252
# copying images 253
# copying images 254
# copying images 255
# copying images 256
# copying images 257
# copying images 258
# copying images 259
# copying images 260
# copying images 261
# copying images 262
# copying images 263
# copying images 264
# copying images 265
# copying images 266
# copying images 267
# copying images 268
# copying images 269
# copying images 270
# copying images 271
# copying images 272
# copying images 273
# copying images 274
# copying images 275
# copying images 276
# copying images 277
# copying images 278
# copying images 279
# copying images 280
# copying images 281
# copying images 282
# copying images 283
# copying images 284
# copying images 285
# copying images 286
# copying images 287
# copying images 288
# copying images 289
# copying images 290
# copying images 291
# copying images 292
# copying images 293
# copying images 294
# copying images 295
# copying images 296
# copying images 297
# copying images 298
# copying images 299
# copying images 300
# copying images 301
# copying images 302
# copying images 303
# copying images 304
# copying images 305
# copying images 306
# copying images 307
# copying images 308
# copying images 309
# copying images 310
# copying images 311
# copying images 312
# copying images 313
# copying images 314
# copying images 315
# copying images 316
# copying images 317
# copying images 318
# copying images 319
# copying images 320
# copying images 321
# copying images 322
# copying images 323
# copying images 324
# copying images 325
# copying images 326
# copying images 327
# copying images 328
# copying images 329
# copying images 330
# copying images 331
# copying images 332
# copying images 333
# copying images 334
# copying images 335
# copying images 336
# copying images 337
# copying images 338
# copying images 339
# copying images 340
# copying images 341
# copying images 342
# copying images 343
# copying images 344
# copying images 345
# copying images 346
# copying images 347
# copying images 348
# copying images 349
# copying images 350
# copying images 351
# copying images 352
# copying images 353
# copying images 354
# copying images 355
# copying images 356
# copying images 357
# copying images 358
# copying images 359
# copying images 360
# copying images 361
# copying images 362
# copying images 363
# copying images 364
# copying images 365
# copying images 366
# copying images 367
# copying images 368
# copying images 369
# copying images 370
# copying images 371
# copying images 372
# copying images 373
# copying images 374
# copying images 375
# copying images 376
# copying images 377
# copying images 378
# copying images 379
# copying images 380
# copying images 381
# copying images 382
# copying images 383
# copying images 384
# copying images 385
# copying images 386
# copying images 387
# copying images 388
# copying images 389
# copying images 390
# copying images 391
# copying images 392
# copying images 393
# copying images 394
# copying images 395
# copying images 396
# copying images 397
# copying images 398
# copying images 399
# copying images 400
# copying images 401
# copying images 402
# copying images 403
# copying images 404
# copying images 405
# copying images 406
# copying images 407
# copying images 408
# copying images 409
# copying images 410
# copying images 411
# copying images 412
# copying images 413
# copying images 414
# copying images 415
# copying images 416
# copying images 417
# copying images 418
# copying images 419
# copying images 420
# copying images 421
# copying images 422
# copying images 423
# copying images 424
# copying images 425
# copying images 426
# copying images 427
# copying images 428
# copying images 429
# copying images 430
# copying images 431
# copying images 432
# copying images 433
# copying images 434
# copying images 435
# copying images 436
# copying images 437
# copying images 438
# copying images 439
# copying images 440
# copying images 441
# copying images 442
# copying images 443
# copying images 444
# copying images 445
# copying images 446
# copying images 447
# copying images 448
# copying images 449
# copying images 450
# copying images 451
# copying images 452
# copying images 453
# copying images 454
# copying images 455
# copying images 456
# copying images 457
# copying images 458

# %%
random.shuffle(image_sunrise)
sunrise='/content/drive/MyDrive/Weather Image Classification/Sunrise'
for i in range(197):
  images=image_sunrise[i]
  image_path=os.path.join(sunrise,images)
  target_path=os.path.join('/content/Test/Sunrise',images)
  shutil.copy2(image_path,target_path)
  print('copying images',i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# copying images 50
# copying images 51
# copying images 52
# copying images 53
# copying images 54
# copying images 55
# copying images 56
# copying images 57
# copying images 58
# copying images 59
# copying images 60
# copying images 61
# copying images 62
# copying images 63
# copying images 64
# copying images 65
# copying images 66
# copying images 67
# copying images 68
# copying images 69
# copying images 70
# copying images 71
# copying images 72
# copying images 73
# copying images 74
# copying images 75
# copying images 76
# copying images 77
# copying images 78
# copying images 79
# copying images 80
# copying images 81
# copying images 82
# copying images 83
# copying images 84
# copying images 85
# copying images 86
# copying images 87
# copying images 88
# copying images 89
# copying images 90
# copying images 91
# copying images 92
# copying images 93
# copying images 94
# copying images 95
# copying images 96
# copying images 97
# copying images 98
# copying images 99
# copying images 100
# copying images 101
# copying images 102
# copying images 103
# copying images 104
# copying images 105
# copying images 106
# copying images 107
# copying images 108
# copying images 109
# copying images 110
# copying images 111
# copying images 112
# copying images 113
# copying images 114
# copying images 115
# copying images 116
# copying images 117
# copying images 118
# copying images 119
# copying images 120
# copying images 121
# copying images 122
# copying images 123
# copying images 124
# copying images 125
# copying images 126
# copying images 127
# copying images 128
# copying images 129
# copying images 130
# copying images 131
# copying images 132
# copying images 133
# copying images 134
# copying images 135
# copying images 136
# copying images 137
# copying images 138
# copying images 139
# copying images 140
# copying images 141
# copying images 142
# copying images 143
# copying images 144
# copying images 145
# copying images 146
# copying images 147
# copying images 148
# copying images 149
# copying images 150
# copying images 151
# copying images 152
# copying images 153
# copying images 154
# copying images 155
# copying images 156
# copying images 157
# copying images 158
# copying images 159
# copying images 160
# copying images 161
# copying images 162
# copying images 163
# copying images 164
# copying images 165
# copying images 166
# copying images 167
# copying images 168
# copying images 169
# copying images 170
# copying images 171
# copying images 172
# copying images 173
# copying images 174
# copying images 175
# copying images 176
# copying images 177
# copying images 178
# copying images 179
# copying images 180
# copying images 181
# copying images 182
# copying images 183
# copying images 184
# copying images 185
# copying images 186
# copying images 187
# copying images 188
# copying images 189
# copying images 190
# copying images 191
# copying images 192
# copying images 193
# copying images 194
# copying images 195
# copying images 196

# %% [markdown]
# CNN MODEL BUILDING

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img

# %%
Train_dir='/content/Train'
Test_dir='/content/Test'

train_data=ImageDataGenerator(rescale=1/255.0,horizontal_flip=True,shear_range=0.4)

test_data=ImageDataGenerator(rescale=1/255.0)

# %%
os.listdir('/content/Train')
# Out:
# ['Cloudy', 'Shine', 'Rain', 'Sunrise']

# %%
training_set=train_data.flow_from_directory(Train_dir,target_size=(224,224),batch_size=40,color_mode='rgb',class_mode='categorical')

test_set=test_data.flow_from_directory(Test_dir,target_size=(224,224),batch_size=40,color_mode='rgb',class_mode='categorical')
# Out:
# Found 1985 images belonging to 4 classes.
# Found 749 images belonging to 4 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D,BatchNormalization,Dropout
from tensorflow.keras import optimizers,regularizers
from tensorflow.keras import layers, Model

# %%
model=Sequential()

model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(Flatten())

model.add(Dense(32,activation='relu'))
model.add(Dense(4,activation='softmax'))

print(model.summary())

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

history=model.fit(training_set,epochs=10,validation_data=test_set, steps_per_epoch=len(training_set),validation_steps=len(test_set))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  flatten (Flatten)           (None, 346112)            0
#
#  dense (Dense)               (None, 32)                11075616
#
#  dense_1 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 11,168,996
# Trainable params: 11,168,996
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
#  3/50 [>.............................] - ETA: 3:15 - loss: 3.0046 - accuracy: 0.2250
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 50/50 [==============================] - 234s 5s/step - loss: 1.1631 - accuracy: 0.5264 - val_loss: 0.9571 - val_accuracy: 0.5874
# Epoch 2/10
# 50/50 [==============================] - 231s 5s/step - loss: 0.7888 - accuracy: 0.6791 - val_loss: 0.6409 - val_accuracy: 0.7850
# Epoch 3/10
# 50/50 [==============================] - 231s 5s/step - loss: 0.5870 - accuracy: 0.7673 - val_loss: 0.4996 - val_accuracy: 0.8064
# Epoch 4/10
# 50/50 [==============================] - 231s 5s/step - loss: 0.4304 - accuracy: 0.8363 - val_loss: 0.2855 - val_accuracy: 0.9146
# Epoch 5/10
# 50/50 [==============================] - 230s 5s/step - loss: 0.3478 - accuracy: 0.8715 - val_loss: 0.1914 - val_accuracy: 0.9439
# Epoch 6/10
# 50/50 [==============================] - 230s 5s/step - loss: 0.2418 - accuracy: 0.9128 - val_loss: 0.1738 - val_accuracy: 0.9493
# Epoch 7/10
# 50/50 [==============================] - 231s 5s/step - loss: 0.1671 - accuracy: 0.9446 - val_loss: 0.1792 - val_accuracy: 0.9573
# Epoch 8/10
# 50/50 [==============================] - 231s 5s/step - loss: 0.1337 - accuracy: 0.9521 - val_loss: 0.1893 - val_accuracy: 0.9533
# Epoch 9/10
# 50/50 [==============================] - 231s 5s/step - loss: 0.1220 - accuracy: 0.9592 - val_loss: 0.3857 - val_accuracy: 0.8865
# Epoch 10/10
# 50/50 [==============================] - 231s 5s/step - loss: 0.1371 - accuracy: 0.9562 - val_loss: 0.4452 - val_accuracy: 0.8732

# %%
ev=model.evaluate(test_set)
# Out:
# 19/19 [==============================] - 28s 1s/step - loss: 0.4452 - accuracy: 0.8732

# %% [markdown]
# TRANSFER LEARNING _ XCEPTION

# %%
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import preprocess_input

# %%
xcep=Xception(include_top=False,weights='imagenet',input_shape=(224,224,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
for layer in xcep.layers:
  layer.trainable=False

# %%
x=Flatten()(xcep.output)
prediction=Dense(4,activation='softmax')(x)

m=Model(inputs=xcep.input,outputs=prediction)

m.summary()

m.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 111, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 111, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 109, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 109, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 109, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 109, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 109, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 109, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_3 (Conv2D)              (None, 55, 55, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 55, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 55, 128)  512        ['conv2d_3[0][0]']
#  alization)
#
#  add (Add)                      (None, 55, 55, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 55, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 55, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 55, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 55, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 28, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 28, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 28, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 28, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 14, 728)  2912       ['conv2d_5[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 14, 14, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 14, 14, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 14, 14, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 14, 14, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 14, 14, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 14, 14, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 14, 14, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 14, 14, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 14, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 14, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 7, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 7, 1024)  4096        ['conv2d_6[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 7, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 7, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 7, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 7, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 7, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 7, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  flatten_1 (Flatten)            (None, 100352)       0           ['block14_sepconv2_act[0][0]']
#
#  dense_2 (Dense)                (None, 4)            401412      ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 21,262,892
# Trainable params: 401,412
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %%
m.fit(training_set,epochs=5,validation_data=test_set)
# Out:
# Epoch 1/5
#  4/50 [=>............................] - ETA: 5:24 - loss: 3.7089 - accuracy: 0.3562
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 50/50 [==============================] - 477s 10s/step - loss: 1.7250 - accuracy: 0.7169 - val_loss: 0.4076 - val_accuracy: 0.9052
# Epoch 2/5
# 50/50 [==============================] - 471s 9s/step - loss: 0.3946 - accuracy: 0.8972 - val_loss: 0.4487 - val_accuracy: 0.9025
# Epoch 3/5
# 50/50 [==============================] - 470s 9s/step - loss: 0.2311 - accuracy: 0.9340 - val_loss: 0.3470 - val_accuracy: 0.9186
# Epoch 4/5
# 50/50 [==============================] - 470s 9s/step - loss: 0.1297 - accuracy: 0.9617 - val_loss: 0.5791 - val_accuracy: 0.8772
# Epoch 5/5
# 50/50 [==============================] - 471s 9s/step - loss: 0.1912 - accuracy: 0.9491 - val_loss: 0.2726 - val_accuracy: 0.9653

# %%
pred=m.evaluate(test_set)
# Out:
# 19/19 [==============================] - 125s 7s/step - loss: 0.2726 - accuracy: 0.9653
